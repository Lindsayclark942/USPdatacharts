# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib.patches import Shadow
# %matplotlib inline
import os

# %% [markdown]
# ## Pie Chart for USP Poverty Levels

# %% [markdown]
# USPpovlev = 'High Poverty Area', 'Low Poverty Area'
# USPpovperc = [74.5, 25.2]
# #expl1 = (0.06, 0)
# #color = ['red', 'blue']

# %% [markdown]
# the_grid = GridSpec(1,1)
# plt.subplot(the_grid[0, 0], aspect=1)
# plt.pie(USPpovperc, labels=USPpovlev,autopct='%1.1f%%', radius=1)
# # explode=expl1, labeldistance=0.3, pctdistance=0.8, colors=color
# #plt.legend(loc=3)
# plt.text(-0.1, -1.2, 'a) USP', fontsize=12)
#
# plt.savefig('USPpovPie.png')
# #plt.show()

# %% [markdown]
# ## Pie Chart for CSDA Poverty Levels

# %% [markdown]
# CSDApovlev = 'High Poverty Area', 'Low Poverty Area'
# CSDApovperc = [72.6, 27.3]
# expl2 = (0.06, 0)

# %% [markdown]
# the_grid = GridSpec(1,1)
# plt.subplot(the_grid[0, 0], aspect=1)
# plt.pie(CSDApovperc, labels=CSDApovlev,autopct='%1.1f%%', shadow = True, explode=expl2)
# #plt.title('CSDA Students Poverty Levels by ZIP Code', fontsize=16)
#
# #plt.savefig('CSDApovPie.png')
# plt.show()

# %% [markdown]
# ## Pie Chart for USP Ethnicity

# %% [markdown]
# USPethName = 'Black/African American', 'Hispanic/Latino', 'Asian', 'White', 'Other'
# USPethperc = [60, 18, 3, 18, 1]
# expl3 = (0.05, 0.05, 0, 0, 0)

# %% [markdown]
# the_grid = GridSpec(1,1)
# plt.subplot(the_grid[0, 0], aspect=1)
# plt.pie(USPethperc, labels=USPethName,autopct='%1.0f%%', shadow = True, radius=1.5, explode=expl3)
# #plt.title('USP Student Ethnicity', fontsize=20)
#
# #plt.savefig('USPethPie.png')
# plt.tight_layout(True)
# plt.show()

# %% [markdown]
# ## Pie Chart for CSDA Ethnicity

# %% [markdown]
# CSDAethName = 'Black/African American', 'Hispanic/Latino', 'Asian', 'White', 'Other'
# CSDAethperc = [48, 17, 9, 20, 6]
# expl4 = (0.05, 0.05, 0, 0, 0)

# %% [markdown]
# the_grid = GridSpec(1,1)
# plt.subplot(the_grid[0, 0], aspect=1)
# plt.pie(CSDAethperc, labels=CSDAethName,autopct='%1.0f%%', shadow = True, radius=1.5, explode=expl4)
# #plt.title('CSDA Student Ethnicity', fontsize=20)
#
# #plt.savefig('CSDAethPie.png')
# plt.show()

# %% [markdown]
# ## USP Gender Chart

# %% [markdown]
# USPgen = 'Male', 'Female'
# USPgenperc = [48, 17, 9, 20, 6]
# expl4 = (0.05, 0.05, 0, 0, 0)

# %% [markdown]
# the_grid = GridSpec(1,1)
# #plt.subplot(the_grid[0, 0], aspect=1)
# #plt.pie(USPgenperc, labels=USPgen,autopct='%1.0f%%', shadow = True, radius=1.5)
# #plt.title('USP Gender', fontsize=20)
#
# #plt.savefig('CSDAethPie.png')
# #plt.show()

# %% [markdown]
# ## Combined Poverty Chart

# %%
USPpovlev = 'High Poverty Area', 'Low Poverty Area'
USPpovperc = [74.5, 25.2]
colors1 = ('#5DA5DA', '#FAA43A')

the_grid1 = GridSpec(1,3) #Creates grid

plt.subplot(the_grid1[0, 2], aspect=1) #puts chart in position on grid
plt.pie(USPpovperc, labels=USPpovlev,autopct='%1.1f%%', radius=2, colors=colors1) 
plt.text(-0.2, -2.5, 'b) USP', fontsize=12)

CSDApovlev = 'High Poverty Area', 'Low Poverty Area'
CSDApovperc = [72.6, 27.3]

plt.subplot(the_grid1[0, 0], aspect=1)
plt.pie(CSDApovperc, labels=CSDApovlev,autopct='%1.1f%%', radius=2, colors=colors1)
plt.text(-0.2, -2.5, 'a) District', fontsize=12)

plt.tight_layout()
plt.savefig('combinedpoverty.png', bbox_inches='tight') #bbox_inches='tight' makes everything fit when tight_layout fails you for the last time
#plt.show()

# %% [markdown]
# ## Combined Ethnicity

# %%
USPethName = 'Black/African American', 'Hispanic/Latino', 'Asian', 'White', 'Other'
USPethperc = [60, 18, 3, 18, 1]
expl1 = (0.18, 0.15, 0, 0, 0)
colors2 = ('#5DA5DA', '#FAA43A', '#60BD68', '#F15854', '#a8a8a8')

the_grid2 = GridSpec(1,4)

plt.subplot(the_grid2[0, 3], aspect=1)
plt.pie(USPethperc, labels=USPethName,autopct='%1.0f%%', radius=2.3, explode=expl1, colors=colors2)
plt.text(-0.5, -3, 'b) USP', fontsize=12) 

CSDAethName = 'Black/African American', 'Hispanic/Latino', 'Asian', 'White', 'Other'
CSDAethperc = [48, 17, 9, 20, 6]
expl2 = (0.18, 0.15, 0, 0, 0)

plt.subplot(the_grid2[0, 0], aspect=1)
plt.pie(CSDAethperc, labels=CSDAethName,autopct='%1.0f%%', radius=2.3, explode=expl2, colors=colors2)
plt.text(-0.5, -3, 'a) District', fontsize=12)

plt.tight_layout()
plt.savefig('combinedethnicity.png', bbox_inches='tight')

# %% [markdown]
# ## Combined Gender

# %%
USPgenlab = 'Male', 'Female'
USPgenperc = [44, 56]
colors3 = ('#5DA5DA', '#F17CB0')

the_grid3 = GridSpec(1,3) #Creates grid

plt.subplot(the_grid3[0, 2], aspect=1) #puts chart in position on grid
plt.pie(USPgenperc, labels=USPgenlab, autopct='%1.0f%%', radius=2, colors=colors3) 
plt.text(-0.5, -2.8, 'b) USP', fontsize=12)

CSDAgenlab = 'Male', 'Female'
CSDAgenperc = [51, 49]

plt.subplot(the_grid3[0, 0], aspect=1)
plt.pie(CSDAgenperc, labels=CSDAgenlab, autopct='%1.0f%%', radius=2, colors=colors3)
plt.text(-0.5, -2.8, 'a) District', fontsize=12)

plt.tight_layout()
plt.savefig('combinedgender.png', bbox_inches='tight') 
#plt.show()
